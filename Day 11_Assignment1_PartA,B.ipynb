# %%
import pandas as pd
import numpy as np
import re

# %%
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""
    
    pattern = '[A-Z][a-z]*'
    p =  re.findall(pattern, simple_string)
    return p
    raise Not good #raise는 오류메시지를 불러주네..
    
#  NotImplementedError()
# Out:
#   File "<ipython-input-44-571b3968d6b6>", line 8
#     raise Not good #raise는 오류메시지를 불러주네..
#               ^
# SyntaxError: invalid syntax

# %%
assert len(names()) == 4, "There are four names in the simple_string" 

#assert는 True이면 오류 메시지 없음

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Jeonghoon Kong\\OneDrive\\Desktop\\Python\\Python_100days of Code'

# %%
f = open (r'C:\Users\Jeonghoon Kong\OneDrive\Desktop\Python\Python_coursera\Course 1 - Notebook Resources\assignments\assignment1\assets\grades.txt')
print(f.read())
# Out:
# Ronald Mayr: A
# Bell Kassulke: B
# Jacqueline Rupp: A
# Alexander Zeller: C
# Valentina Denk: C
# Simon Loidl: B
# Elias Jovanovic: B
# Stefanie Weninger: A
# Fabian Peer: C
# Hakim Botros: B
# Emilie Lorentsen: B
# Herman Karlsen: C
# Nathalie Delacruz: C
# Casey Hartman: C
# Lily Walker : A
# Gerard Wang: C
# Tony Mcdowell: C
# Jake Wood: B
# Fatemeh Akhtar: B
# Kim Weston: B
# Nicholas Beatty: A
# Kirsten Williams: C
# Vaishali Surana: C
# Coby Mccormack: C
# Yasmin Dar: B
# Romy Donnelly: A
# Viswamitra Upandhye: B
# Kendrick Hilpert: A
# Killian Kaufman: B
# Elwood Page: B
# Mukti Patel: A
# Emily Lesch: C
# Elodie Booker: B
# Jedd Kim: A
# Annabel Davies: A
# Adnan Chen: B
# Jonathan Berg: C
# Hank Spinka: B
# Agnes Schneider: C
# Kimberly Green: A
# Lola-Rose Coates: C
# Rose Christiansen: C
# Shirley Hintz: C
# Hannah Bayer: B

# %% [markdown]
# ## Part B
#
# The dataset file in [assets/grades.txt](assets/grades.txt) contains a line separated list of people with their grade in
# a class. Create a regex to generate a list of just those students who received a B in the course.

# %%
import re
def grades():
    with open (r'C:\Users\Jeonghoon Kong\OneDrive\Desktop\Python\Python_coursera\Course 1 - Notebook Resources\assignments\assignment1\assets\grades.txt') as file:
        grades = file.read()
        
        B_grader = '[\w]*[\s][\w]*(?=:[\s]B)'
        
        return re.findall(B_grader,grades)
        
# A(?=B) | Lookahead assertion. This matches
# the expression A only if it is followed by B.   

# [\s]나 [\ ] 나 똑같다.


        
    raise NotImplementedError()

# %%
assert len(grades()) == 16
